# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split, GridSearchCV
from imblearn.over_sampling import SMOTE
from collections import Counter
import pandas as pd
import sys
import datetime
import time
import csv
import pathlib
import os

# %%
def KFold_Validation(X, y, nSplits = 5):
    
    # Initialize the K-fold cross-validator
    kf = KFold(n_splits = nSplits, shuffle = True, random_state = 42)
    
    Testing_Results = {}

    for i, (train_index, test_index) in enumerate(kf.split(X)):
        
        # Split the data into training and testing sets for this fold
        print("KFlod : ", i)
        X_t, X_test = X.iloc[train_index], X.iloc[test_index]
        y_t, y_test = y.iloc[train_index], y.iloc[test_index]

        smo = SMOTE(random_state=42)
        X_train, y_train = smo.fit_resample(X_t, y_t)
        
        # Train the model 
        model = train(X_train, y_train)
    
        # Test the model
        precision, recall, f1 = test(X_test, y_test, model)
        
        # Store the results
        Testing_Results[i] = (precision, recall, f1)
        
    return Testing_Results

# %%
'''
    Change the train method according to classifier used
'''

def train(X_train, y_train):
    """
    Use grid search to find optimal parameters and then test the optimal model
    :param X_train:
    :param y_train:
    :return: None
    """
    # grid search parameter list
    tuned_parameters = {
            "n_neighbors": range(1, 20),
            "weights": ['uniform', 'distance']
    }
    # generate model
    print("Start training : " + "\n")
    grid = GridSearchCV(KNeighborsClassifier(), tuned_parameters, cv=5, scoring='roc_auc', verbose=2, n_jobs=4)
    # Send data to model training
    model = grid.fit(X_train, y_train)
    return model

# %%
def test(X_test, y_test, estimator):
    
    y_pre = estimator.predict(X_test)
    precision = precision_score(y_test, y_pre, labels=None, pos_label=1, average='binary', sample_weight=None)
    recall = recall_score(y_test, y_pre, labels=None, pos_label=1, average='binary', sample_weight=None)
    f1 = f1_score(y_test, y_pre, labels=None, pos_label=1, average='binary', sample_weight=None)

    # precision = precision_score(y_test, y_pre, labels=None, average='macro', sample_weight=None)
    # recall = recall_score(y_test, y_pre, labels=None, average='macro', sample_weight=None)
    # f1 = f1_score(y_test, y_pre, labels=None, average='macro', sample_weight=None)


    print("precision: {:.3}, recall: {:.3}, f1:{:.3}, \n".format(precision, recall, f1))
          
    return precision, recall, f1

# %% [markdown]
# ## Automation

# %%
''' 
    Change the input path accordingly
'''

train_dir = r"C:\Users\manoh\Documents\Project_DSCI\rems_modified\Training_CSV"

Final_Results = {}
for Code_Emb in os.listdir(train_dir):
    print(Code_Emb)
    Final_Results[Code_Emb] = {}
    
    for Tree_Emb in os.listdir(train_dir+"\\"+Code_Emb):
        print("\t"+Tree_Emb.split(".")[0])
        
        curr_dir = train_dir+"\\"+Code_Emb+"\\"+Tree_Emb
        
        data = pd.read_csv(curr_dir, header=None)
        
        X = data.iloc[:, :-1]
        y = data.iloc[:, -1]

        # Get the current time
        start_time = time.time()

        # Execute some code you want to time
        Results = KFold_Validation(X, y, nSplits = 10)

        # Get the elapsed time
        elapsed_time = round((time.time() - start_time)/60, 3)

        print("Elapsed time: ", elapsed_time, " Minutes")
        
        results_ = pd.DataFrame(Results, index=["Precision", "Recall", "F1"]).T
        
    
        Final_Results[Code_Emb][Tree_Emb.split(".")[0]] = dict(results_.describe().loc["mean"])
# Out:
# CodeBERT
# 	deepwalk_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.176, recall: 0.6, f1:0.273,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.333, recall: 0.8, f1:0.471,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.172, recall: 0.556, f1:0.263,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.04, recall: 1.0, f1:0.0769,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.25, recall: 0.636, f1:0.359,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.115, recall: 1.0, f1:0.207,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.1, recall: 0.5, f1:0.167,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.273, recall: 0.9, f1:0.419,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.069, recall: 0.4, f1:0.118,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.156, recall: 0.714, f1:0.256,
#
# Elapsed time:  2.438  Minutes
# 	grarep_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.308, recall: 0.571, f1:0.4,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.273, recall: 0.75, f1:0.4,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.25, recall: 0.5, f1:0.333,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.2, recall: 0.75, f1:0.316,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.5, recall: 0.5, f1:0.5,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.667, recall: 0.444, f1:0.533,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.3, recall: 0.5, f1:0.375,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.375, recall: 0.6, f1:0.462,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.214, recall: 0.75, f1:0.333,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.167, recall: 0.4, f1:0.235,
#
# Elapsed time:  2.569  Minutes
# 	line_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0971, recall: 1.0, f1:0.177,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0971, recall: 1.0, f1:0.177,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0874, recall: 1.0, f1:0.161,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.00971, recall: 1.0, f1:0.0192,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.108, recall: 1.0, f1:0.195,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0294, recall: 1.0, f1:0.0571,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0392, recall: 1.0, f1:0.0755,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.098, recall: 1.0, f1:0.179,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.049, recall: 1.0, f1:0.0935,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0686, recall: 1.0, f1:0.128,
#
# Elapsed time:  2.55  Minutes
# 	node2vec_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.172, recall: 0.5, f1:0.256,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.238, recall: 0.5, f1:0.323,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.121, recall: 0.444, f1:0.19,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0323, recall: 1.0, f1:0.0625,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.241, recall: 0.636, f1:0.35,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.125, recall: 1.0, f1:0.222,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.1, recall: 0.5, f1:0.167,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.29, recall: 0.9, f1:0.439,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0714, recall: 0.4, f1:0.121,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.167, recall: 0.714, f1:0.27,
#
# Elapsed time:  2.605  Minutes
# 	prone_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.152, recall: 0.7, f1:0.25,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.139, recall: 0.5, f1:0.217,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.188, recall: 1.0, f1:0.316,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0208, recall: 1.0, f1:0.0408,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.116, recall: 0.455, f1:0.185,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0244, recall: 0.333, f1:0.0455,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0204, recall: 0.25, f1:0.0377,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.208, recall: 1.0, f1:0.345,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.093, recall: 0.8, f1:0.167,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0784, recall: 0.571, f1:0.138,
#
# Elapsed time:  2.201  Minutes
# 	sdne_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.211, recall: 0.5, f1:0.296,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.214, recall: 0.375, f1:0.273,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.417, recall: 0.385, f1:0.4,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.1, recall: 0.333, f1:0.154,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.2, recall: 0.6, f1:0.3,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.4, recall: 0.5, f1:0.444,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.12, recall: 0.75, f1:0.207,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.167, recall: 0.182, f1:0.174,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0625, recall: 0.2, f1:0.0952,
#
# KFlod :  9
# Start training :
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0667, recall: 0.2, f1:0.1,
#
# Elapsed time:  3.003  Minutes
# 	walklets_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0725, recall: 0.833, f1:0.133,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.106, recall: 0.875, f1:0.189,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.169, recall: 1.0, f1:0.29,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.134, recall: 1.0, f1:0.237,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0492, recall: 0.75, f1:0.0923,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0714, recall: 1.0, f1:0.133,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0615, recall: 0.667, f1:0.113,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0615, recall: 0.8, f1:0.114,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0952, recall: 0.857, f1:0.171,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0333, recall: 1.0, f1:0.0645,
#
# Elapsed time:  2.694  Minutes
# CodeGPT
# 	deepwalk_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.147, recall: 0.5, f1:0.227,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.242, recall: 0.8, f1:0.372,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.128, recall: 0.556, f1:0.208,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.027, recall: 1.0, f1:0.0526,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.216, recall: 0.727, f1:0.333,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0857, recall: 1.0, f1:0.158,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0645, recall: 0.5, f1:0.114,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.16, recall: 0.8, f1:0.267,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0263, recall: 0.2, f1:0.0465,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.125, recall: 0.714, f1:0.213,
#
# Elapsed time:  2.913  Minutes
# 	grarep_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0986, recall: 1.0, f1:0.179,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0429, recall: 0.75, f1:0.0811,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0896, recall: 0.75, f1:0.16,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0494, recall: 1.0, f1:0.0941,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.114, recall: 1.0, f1:0.205,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.104, recall: 0.889, f1:0.186,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0633, recall: 0.833, f1:0.118,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0606, recall: 0.8, f1:0.113,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0494, recall: 1.0, f1:0.0941,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0667, recall: 1.0, f1:0.125,
#
# Elapsed time:  2.483  Minutes
# 	line_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0971, recall: 1.0, f1:0.177,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.098, recall: 1.0, f1:0.179,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0874, recall: 1.0, f1:0.161,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.00971, recall: 1.0, f1:0.0192,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.109, recall: 1.0, f1:0.196,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0294, recall: 1.0, f1:0.0571,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0392, recall: 1.0, f1:0.0755,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.098, recall: 1.0, f1:0.179,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0495, recall: 1.0, f1:0.0943,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0686, recall: 1.0, f1:0.128,
#
# Elapsed time:  3.081  Minutes
# 	node2vec_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.147, recall: 0.5, f1:0.227,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.24, recall: 0.6, f1:0.343,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0976, recall: 0.444, f1:0.16,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0303, recall: 1.0, f1:0.0588,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.188, recall: 0.545, f1:0.279,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.107, recall: 1.0, f1:0.194,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.08, recall: 0.5, f1:0.138,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.216, recall: 0.8, f1:0.34,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.027, recall: 0.2, f1:0.0476,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.139, recall: 0.714, f1:0.233,
#
# Elapsed time:  2.794  Minutes
# 	prone_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.098, recall: 1.0, f1:0.179,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.105, recall: 1.0, f1:0.19,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0882, recall: 1.0, f1:0.162,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0098, recall: 1.0, f1:0.0194,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.102, recall: 0.909, f1:0.183,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0297, recall: 1.0, f1:0.0577,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.04, recall: 1.0, f1:0.0769,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.1, recall: 1.0, f1:0.182,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.05, recall: 1.0, f1:0.0952,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0606, recall: 0.857, f1:0.113,
#
# Elapsed time:  2.463  Minutes
# 	sdne_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.143, recall: 0.875, f1:0.246,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.125, recall: 0.625, f1:0.208,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.19, recall: 0.615, f1:0.291,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0833, recall: 1.0, f1:0.154,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.105, recall: 0.8, f1:0.186,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.179, recall: 0.875, f1:0.298,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.103, recall: 0.75, f1:0.182,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.19, recall: 0.727, f1:0.302,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0968, recall: 0.6, f1:0.167,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0938, recall: 0.6, f1:0.162,
#
# Elapsed time:  3.204  Minutes
# 	walklets_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0725, recall: 0.833, f1:0.133,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.111, recall: 0.875, f1:0.197,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.141, recall: 1.0, f1:0.247,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.148, recall: 1.0, f1:0.257,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0508, recall: 0.75, f1:0.0952,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0625, recall: 1.0, f1:0.118,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0656, recall: 0.667, f1:0.119,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0556, recall: 0.8, f1:0.104,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.102, recall: 0.857, f1:0.182,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0299, recall: 1.0, f1:0.058,
#
# Elapsed time:  2.729  Minutes
# CodeT5
# 	deepwalk_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.102, recall: 0.6, f1:0.174,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.167, recall: 1.0, f1:0.286,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.118, recall: 0.667, f1:0.2,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0175, recall: 1.0, f1:0.0345,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.179, recall: 0.909, f1:0.299,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0566, recall: 1.0, f1:0.107,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0566, recall: 0.75, f1:0.105,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.164, recall: 1.0, f1:0.282,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0714, recall: 0.8, f1:0.131,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0893, recall: 0.714, f1:0.159,
#
# Elapsed time:  2.797  Minutes
# 	grarep_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.147, recall: 0.714, f1:0.244,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.06, recall: 0.75, f1:0.111,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.129, recall: 0.5, f1:0.205,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.118, recall: 1.0, f1:0.211,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.2, recall: 0.75, f1:0.316,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.25, recall: 0.444, f1:0.32,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.138, recall: 0.667, f1:0.229,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.069, recall: 0.4, f1:0.118,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0789, recall: 0.75, f1:0.143,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.08, recall: 0.4, f1:0.133,
#
# Elapsed time:  3.443  Minutes
# 	line_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0971, recall: 1.0, f1:0.177,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0971, recall: 1.0, f1:0.177,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0874, recall: 1.0, f1:0.161,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.00971, recall: 1.0, f1:0.0192,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.108, recall: 1.0, f1:0.195,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0294, recall: 1.0, f1:0.0571,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0392, recall: 1.0, f1:0.0755,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.098, recall: 1.0, f1:0.179,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.049, recall: 1.0, f1:0.0935,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0686, recall: 1.0, f1:0.128,
#
# Elapsed time:  2.431  Minutes
# 	node2vec_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.111, recall: 0.6, f1:0.188,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.174, recall: 0.8, f1:0.286,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.098, recall: 0.556, f1:0.167,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0208, recall: 1.0, f1:0.0408,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.173, recall: 0.818, f1:0.286,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0625, recall: 1.0, f1:0.118,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0465, recall: 0.5, f1:0.0851,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.179, recall: 1.0, f1:0.303,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0526, recall: 0.6, f1:0.0968,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.102, recall: 0.714, f1:0.179,
#
# Elapsed time:  2.785  Minutes
# 	prone_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.12, recall: 1.0, f1:0.215,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.115, recall: 0.9, f1:0.205,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.103, recall: 1.0, f1:0.188,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0128, recall: 1.0, f1:0.0253,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0941, recall: 0.727, f1:0.167,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0127, recall: 0.333, f1:0.0244,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0353, recall: 0.75, f1:0.0674,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.118, recall: 1.0, f1:0.211,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0617, recall: 1.0, f1:0.116,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0471, recall: 0.571, f1:0.087,
#
# Elapsed time:  2.421  Minutes
# 	sdne_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.125, recall: 1.0, f1:0.222,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.106, recall: 0.625, f1:0.182,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.208, recall: 0.846, f1:0.333,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.06, recall: 1.0, f1:0.113,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0909, recall: 1.0, f1:0.167,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.174, recall: 1.0, f1:0.296,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0417, recall: 0.5, f1:0.0769,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.176, recall: 0.818, f1:0.29,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.102, recall: 1.0, f1:0.185,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0625, recall: 0.6, f1:0.113,
#
# Elapsed time:  2.756  Minutes
# 	walklets_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0594, recall: 1.0, f1:0.112,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0825, recall: 1.0, f1:0.152,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.1, recall: 1.0, f1:0.182,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0968, recall: 1.0, f1:0.176,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0404, recall: 1.0, f1:0.0777,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0426, recall: 1.0, f1:0.0816,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0632, recall: 1.0, f1:0.119,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0505, recall: 1.0, f1:0.0962,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0714, recall: 1.0, f1:0.133,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0202, recall: 1.0, f1:0.0396,
#
# Elapsed time:  2.39  Minutes
# CoTexT
# 	deepwalk_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.136, recall: 0.6, f1:0.222,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.209, recall: 0.9, f1:0.34,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.128, recall: 0.667, f1:0.214,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.02, recall: 1.0, f1:0.0392,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.149, recall: 0.636, f1:0.241,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0732, recall: 1.0, f1:0.136,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0435, recall: 0.5, f1:0.08,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.17, recall: 0.9, f1:0.286,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.087, recall: 0.8, f1:0.157,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.111, recall: 0.714, f1:0.192,
#
# Elapsed time:  2.753  Minutes
# 	grarep_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.167, recall: 0.571, f1:0.258,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0811, recall: 0.75, f1:0.146,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.133, recall: 0.5, f1:0.211,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.143, recall: 1.0, f1:0.25,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.217, recall: 0.625, f1:0.323,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.259, recall: 0.778, f1:0.389,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.19, recall: 0.667, f1:0.296,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.143, recall: 0.6, f1:0.231,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.1, recall: 0.75, f1:0.176,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.1, recall: 0.4, f1:0.16,
#
# Elapsed time:  2.582  Minutes
# 	line_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0971, recall: 1.0, f1:0.177,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0971, recall: 1.0, f1:0.177,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0874, recall: 1.0, f1:0.161,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.00971, recall: 1.0, f1:0.0192,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.108, recall: 1.0, f1:0.195,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0294, recall: 1.0, f1:0.0571,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0392, recall: 1.0, f1:0.0755,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.098, recall: 1.0, f1:0.179,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.049, recall: 1.0, f1:0.0935,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0686, recall: 1.0, f1:0.128,
#
# Elapsed time:  2.831  Minutes
# 	node2vec_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.132, recall: 0.5, f1:0.208,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.25, recall: 0.8, f1:0.381,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.111, recall: 0.556, f1:0.185,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0263, recall: 1.0, f1:0.0513,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.195, recall: 0.727, f1:0.308,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.1, recall: 1.0, f1:0.182,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0938, recall: 0.75, f1:0.167,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.22, recall: 0.9, f1:0.353,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0476, recall: 0.4, f1:0.0851,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.128, recall: 0.714, f1:0.217,
#
# Elapsed time:  2.8  Minutes
# 	prone_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.122, recall: 0.9, f1:0.214,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0952, recall: 0.6, f1:0.164,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.111, recall: 1.0, f1:0.2,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0135, recall: 1.0, f1:0.0267,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0986, recall: 0.636, f1:0.171,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0141, recall: 0.333, f1:0.027,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0263, recall: 0.5, f1:0.05,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.118, recall: 1.0, f1:0.211,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0625, recall: 1.0, f1:0.118,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0625, recall: 0.714, f1:0.115,
#
# Elapsed time:  2.474  Minutes
# 	sdne_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.123, recall: 0.875, f1:0.215,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.119, recall: 0.625, f1:0.2,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.216, recall: 0.846, f1:0.344,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.075, recall: 1.0, f1:0.14,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.1, recall: 1.0, f1:0.182,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.175, recall: 0.875, f1:0.292,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0833, recall: 0.75, f1:0.15,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.167, recall: 0.727, f1:0.271,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.104, recall: 1.0, f1:0.189,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0698, recall: 0.6, f1:0.125,
#
# Elapsed time:  2.957  Minutes
# 	walklets_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0632, recall: 1.0, f1:0.119,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0833, recall: 1.0, f1:0.154,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.111, recall: 1.0, f1:0.2,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0968, recall: 1.0, f1:0.176,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.044, recall: 1.0, f1:0.0842,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.044, recall: 1.0, f1:0.0842,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0562, recall: 0.833, f1:0.105,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0515, recall: 1.0, f1:0.098,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0769, recall: 1.0, f1:0.143,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0213, recall: 1.0, f1:0.0417,
#
# Elapsed time:  2.415  Minutes
# GraphCodeBERT
# 	deepwalk_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.154, recall: 0.6, f1:0.245,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.308, recall: 0.8, f1:0.444,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.152, recall: 0.556, f1:0.238,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0278, recall: 1.0, f1:0.0541,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.25, recall: 0.727, f1:0.372,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0938, recall: 1.0, f1:0.171,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0667, recall: 0.5, f1:0.118,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.217, recall: 1.0, f1:0.357,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0938, recall: 0.6, f1:0.162,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.143, recall: 0.714, f1:0.238,
#
# Elapsed time:  2.982  Minutes
# 	grarep_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.267, recall: 0.571, f1:0.364,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.133, recall: 0.5, f1:0.211,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.2, recall: 0.5, f1:0.286,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.188, recall: 0.75, f1:0.3,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.357, recall: 0.625, f1:0.455,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.571, recall: 0.444, f1:0.5,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.2, recall: 0.5, f1:0.286,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.286, recall: 0.4, f1:0.333,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.15, recall: 0.75, f1:0.25,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.167, recall: 0.4, f1:0.235,
#
# Elapsed time:  2.678  Minutes
# 	line_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0971, recall: 1.0, f1:0.177,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0971, recall: 1.0, f1:0.177,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0874, recall: 1.0, f1:0.161,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.00971, recall: 1.0, f1:0.0192,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.108, recall: 1.0, f1:0.195,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0294, recall: 1.0, f1:0.0571,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0392, recall: 1.0, f1:0.0755,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.098, recall: 1.0, f1:0.179,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.049, recall: 1.0, f1:0.0935,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0686, recall: 1.0, f1:0.128,
#
# Elapsed time:  2.851  Minutes
# 	node2vec_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.167, recall: 0.6, f1:0.261,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.292, recall: 0.7, f1:0.412,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.139, recall: 0.556, f1:0.222,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0357, recall: 1.0, f1:0.069,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.25, recall: 0.727, f1:0.372,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.13, recall: 1.0, f1:0.231,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0833, recall: 0.5, f1:0.143,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.273, recall: 0.9, f1:0.419,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0645, recall: 0.4, f1:0.111,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.152, recall: 0.714, f1:0.25,
#
# Elapsed time:  2.655  Minutes
# 	prone_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.125, recall: 0.7, f1:0.212,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.122, recall: 0.6, f1:0.203,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.133, recall: 0.889, f1:0.232,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0154, recall: 1.0, f1:0.0303,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.086, recall: 0.727, f1:0.154,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0192, recall: 0.333, f1:0.0364,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0317, recall: 0.5, f1:0.0597,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.147, recall: 1.0, f1:0.256,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0581, recall: 1.0, f1:0.11,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0645, recall: 0.571, f1:0.116,
#
# Elapsed time:  2.421  Minutes
# 	sdne_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.125, recall: 0.625, f1:0.208,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.133, recall: 0.5, f1:0.211,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.231, recall: 0.692, f1:0.346,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0909, recall: 1.0, f1:0.167,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.111, recall: 0.6, f1:0.188,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.185, recall: 0.625, f1:0.286,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.103, recall: 0.75, f1:0.182,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.143, recall: 0.545, f1:0.226,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0667, recall: 0.4, f1:0.114,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0455, recall: 0.2, f1:0.0741,
#
# Elapsed time:  2.758  Minutes
# 	walklets_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0633, recall: 0.833, f1:0.118,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.1, recall: 0.875, f1:0.179,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.135, recall: 1.0, f1:0.238,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.138, recall: 1.0, f1:0.243,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0597, recall: 1.0, f1:0.113,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0635, recall: 1.0, f1:0.119,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0615, recall: 0.667, f1:0.113,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0556, recall: 0.8, f1:0.104,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.1, recall: 1.0, f1:0.182,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0263, recall: 1.0, f1:0.0513,
#
# Elapsed time:  2.568  Minutes
# PLBART
# 	deepwalk_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.15, recall: 0.6, f1:0.24,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.296, recall: 0.8, f1:0.432,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.161, recall: 0.556, f1:0.25,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.027, recall: 1.0, f1:0.0526,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.25, recall: 0.636, f1:0.359,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0588, recall: 0.667, f1:0.108,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0741, recall: 0.5, f1:0.129,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.211, recall: 0.8, f1:0.333,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0667, recall: 0.4, f1:0.114,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.147, recall: 0.714, f1:0.244,
#
# Elapsed time:  3.123  Minutes
# 	grarep_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.286, recall: 0.571, f1:0.381,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.273, recall: 0.75, f1:0.4,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.158, recall: 0.375, f1:0.222,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.188, recall: 0.75, f1:0.3,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.417, recall: 0.625, f1:0.5,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.6, recall: 0.333, f1:0.429,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.273, recall: 0.5, f1:0.353,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.3, recall: 0.6, f1:0.4,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.188, recall: 0.75, f1:0.3,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.154, recall: 0.4, f1:0.222,
#
# Elapsed time:  2.92  Minutes
# 	line_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0971, recall: 1.0, f1:0.177,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0971, recall: 1.0, f1:0.177,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0874, recall: 1.0, f1:0.161,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.00971, recall: 1.0, f1:0.0192,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.108, recall: 1.0, f1:0.195,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0294, recall: 1.0, f1:0.0571,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0392, recall: 1.0, f1:0.0755,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.098, recall: 1.0, f1:0.179,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.049, recall: 1.0, f1:0.0935,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0686, recall: 1.0, f1:0.128,
#
# Elapsed time:  3.15  Minutes
# 	node2vec_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.143, recall: 0.5, f1:0.222,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.304, recall: 0.7, f1:0.424,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.139, recall: 0.556, f1:0.222,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0357, recall: 1.0, f1:0.069,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.233, recall: 0.636, f1:0.341,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.125, recall: 1.0, f1:0.222,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0909, recall: 0.5, f1:0.154,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.265, recall: 0.9, f1:0.409,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.069, recall: 0.4, f1:0.118,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.161, recall: 0.714, f1:0.263,
#
# Elapsed time:  2.564  Minutes
# 	prone_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.115, recall: 0.7, f1:0.197,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.109, recall: 0.6, f1:0.185,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.148, recall: 0.889, f1:0.254,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0169, recall: 1.0, f1:0.0333,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.103, recall: 0.545, f1:0.174,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0182, recall: 0.333, f1:0.0345,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0312, recall: 0.5, f1:0.0588,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.156, recall: 1.0, f1:0.27,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0625, recall: 0.6, f1:0.113,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0566, recall: 0.429, f1:0.1,
#
# Elapsed time:  2.52  Minutes
# 	sdne_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.143, recall: 0.625, f1:0.233,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.125, recall: 0.5, f1:0.2,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.233, recall: 0.769, f1:0.357,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0968, recall: 1.0, f1:0.176,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.1, recall: 0.8, f1:0.178,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.167, recall: 0.625, f1:0.263,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0968, recall: 0.75, f1:0.171,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.143, recall: 0.545, f1:0.226,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0645, recall: 0.4, f1:0.111,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.05, recall: 0.2, f1:0.08,
#
# Elapsed time:  2.688  Minutes
# 	walklets_cg
# KFlod :  0
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0633, recall: 0.833, f1:0.118,
#
# KFlod :  1
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0897, recall: 0.875, f1:0.163,
#
# KFlod :  2
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.13, recall: 1.0, f1:0.23,
#
# KFlod :  3
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.12, recall: 1.0, f1:0.214,
#
# KFlod :  4
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0541, recall: 1.0, f1:0.103,
#
# KFlod :  5
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0597, recall: 1.0, f1:0.113,
#
# KFlod :  6
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0735, recall: 0.833, f1:0.135,
#
# KFlod :  7
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0533, recall: 0.8, f1:0.1,
#
# KFlod :  8
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.0857, recall: 0.857, f1:0.156,
#
# KFlod :  9
# Start training :
#
# Fitting 5 folds for each of 38 candidates, totalling 190 fits
# precision: 0.027, recall: 1.0, f1:0.0526,
#
# Elapsed time:  2.163  Minutes

# %% [markdown]
# ## Final Output File

# %%
df = pd.DataFrame(Final_Results)

dic = {}
i = 0
for code_emb in df.columns:
    for tree_emb in df.index:
        dic[i] = (code_emb, tree_emb, df.loc[tree_emb, code_emb]['Precision'], df.loc[tree_emb, code_emb]['Recall'], df.loc[tree_emb, code_emb]['F1'])
        i+=1
output = pd.DataFrame(dic, index = ["CodeGraph", "TreeGraph", "Prec", "Recall", "F1"]).T

output.to_csv("KNN_Results.csv")

# %%
output
# Out:
#         CodeGraph    TreeGraph      Prec    Recall        F1
# 0        CodeBERT  deepwalk_cg  0.168555   0.71062   0.26086
# 1        CodeBERT    grarep_cg  0.325304  0.576587  0.388762
# 2        CodeBERT      line_cg  0.068342       1.0   0.12617
# 3        CodeBERT  node2vec_cg  0.155878  0.659509  0.240136
# 4        CodeBERT     prone_cg  0.104026  0.660931   0.17418
# 5        CodeBERT      sdne_cg  0.195731  0.402477  0.244336
# 6        CodeBERT  walklets_cg   0.08546  0.878214  0.153777
# 7         CodeGPT  deepwalk_cg  0.122248  0.679711  0.199179
# 8         CodeGPT    grarep_cg  0.073851  0.902222   0.13553
# 9         CodeGPT      line_cg  0.068592       1.0   0.12659
# 10        CodeGPT  node2vec_cg   0.12717  0.630418  0.202011
# 11        CodeGPT     prone_cg  0.068369  0.976623  0.125899
# 12        CodeGPT      sdne_cg  0.131087  0.746766  0.219516
# 13        CodeGPT  walklets_cg  0.083798  0.878214  0.151055
# 14         CodeT5  deepwalk_cg  0.101998  0.844004  0.177659
# 15         CodeT5    grarep_cg  0.126958   0.63754  0.202887
# 16         CodeT5      line_cg  0.068342       1.0   0.12617
# 17         CodeT5  node2vec_cg  0.101923  0.758802  0.174754
# 18         CodeT5     prone_cg  0.072064  0.828203  0.130465
# 19         CodeT5      sdne_cg  0.114643  0.838934  0.197918
# 20         CodeT5  walklets_cg  0.062691       1.0  0.117002
# 21         CoTexT  deepwalk_cg  0.112679  0.771732  0.190797
# 22         CoTexT    grarep_cg  0.153392  0.664087  0.243994
# 23         CoTexT      line_cg  0.068342       1.0   0.12617
# 24         CoTexT  node2vec_cg  0.130321  0.734711  0.213737
# 25         CoTexT     prone_cg  0.072312  0.768398  0.129621
# 26         CoTexT      sdne_cg  0.123148  0.829843  0.210702
# 27         CoTexT  walklets_cg  0.064821  0.983333  0.120538
# 28  GraphCodeBERT  deepwalk_cg  0.150525  0.749711  0.240006
# 29  GraphCodeBERT    grarep_cg  0.251845  0.544087  0.321876
# 30  GraphCodeBERT      line_cg  0.068342       1.0   0.12617
# 31  GraphCodeBERT  node2vec_cg  0.158546  0.709711  0.248926
# 32  GraphCodeBERT     prone_cg  0.080288  0.732092  0.140985
# 33  GraphCodeBERT      sdne_cg  0.123473  0.593776  0.200149
# 34  GraphCodeBERT  walklets_cg  0.080349    0.9175  0.146022
# 35         PLBART  deepwalk_cg  0.144176  0.667287   0.22627
# 36         PLBART    grarep_cg  0.283458  0.565476  0.350691
# 37         PLBART      line_cg  0.068342       1.0   0.12617
# 38         PLBART  node2vec_cg  0.156601   0.69062  0.244508
# 39         PLBART     prone_cg  0.081718  0.659625   0.14198
# 40         PLBART      sdne_cg    0.1218  0.621469  0.199606
# 41         PLBART  walklets_cg  0.075626  0.919881  0.138346
